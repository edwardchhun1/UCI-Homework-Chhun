# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you
# think through the steps.
#
# Observations:
# * As latitude increases, the trend appears to show a decrease in max temperature in the Northern Hemisphere.
# * There is a strong negative correlation between latitude and the max temperature in the northern hemisphere.
# * There is a very weak positive correlation between latitude and cloudiness for the souther hemisphere.

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import weather API key
from api_keys import weather_api_key

# Getting city date - using long and lat
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

#Setting range for lat and long
lat_range = (-90, 90)
long_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Creating variables to store lat and long combos and also creating variable to store cities
lat_long_rand = []
cities = []

# Create a set of random lat and lng combinations
latitude_rand = np.random.uniform(low=-90.000, high=90.000, size=1500)
longitude_rand = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_long_rand = zip(latitude_rand, longitude_rand)

# Identify nearest city for each lat long combo generated
for lat_long in lat_long_rand:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    
    # If the city is unique, then add it to list of cities
    if city not in cities:
        cities.append(city)

# Print count to confirm working code
len(cities)
# Out:
# 610

# %%
# Creating lists to store values

city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Looking for next value.")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : goba
# Processing Record 2 of Set 1 : coahuayana
# Processing Record 3 of Set 1 : hasaki
# Processing Record 4 of Set 1 : khatanga
# Processing Record 5 of Set 1 : tasiilaq
# Processing Record 6 of Set 1 : naduvattam
# Processing Record 7 of Set 1 : cape town
# Processing Record 8 of Set 1 : bambous virieux
# Processing Record 9 of Set 1 : richards bay
# Processing Record 10 of Set 1 : port alfred
# Processing Record 11 of Set 1 : ribeira grande
# Processing Record 12 of Set 1 : jamestown
# Processing Record 13 of Set 1 : ushuaia
# Processing Record 14 of Set 1 : avarua
# City not found. Looking for next value.
# Processing Record 15 of Set 1 : kutum
# Processing Record 16 of Set 1 : iqaluit
# Processing Record 17 of Set 1 : chokurdakh
# Processing Record 18 of Set 1 : tuktoyaktuk
# Processing Record 19 of Set 1 : nikolskoye
# Processing Record 20 of Set 1 : puerto ayora
# Processing Record 21 of Set 1 : east london
# City not found. Looking for next value.
# City not found. Looking for next value.
# Processing Record 22 of Set 1 : dunedin
# Processing Record 23 of Set 1 : bilma
# Processing Record 24 of Set 1 : castro
# Processing Record 25 of Set 1 : gizo
# Processing Record 26 of Set 1 : punta arenas
# City not found. Looking for next value.
# Processing Record 27 of Set 1 : qaanaaq
# Processing Record 28 of Set 1 : kaitangata
# City not found. Looking for next value.
# Processing Record 29 of Set 1 : upernavik
# Processing Record 30 of Set 1 : san patricio
# Processing Record 31 of Set 1 : saint george
# Processing Record 32 of Set 1 : kapaa
# City not found. Looking for next value.
# Processing Record 33 of Set 1 : mataura
# Processing Record 34 of Set 1 : clyde river
# Processing Record 35 of Set 1 : hilo
# Processing Record 36 of Set 1 : hobart
# Processing Record 37 of Set 1 : rikitea
# Processing Record 38 of Set 1 : strzegom
# City not found. Looking for next value.
# Processing Record 39 of Set 1 : herouville-saint-clair
# Processing Record 40 of Set 1 : new norfolk
# Processing Record 41 of Set 1 : saint-philippe
# Processing Record 42 of Set 1 : los llanos de aridane
# City not found. Looking for next value.
# Processing Record 43 of Set 1 : sao joao da barra
# Processing Record 44 of Set 1 : yura
# Processing Record 45 of Set 1 : sao felix do xingu
# Processing Record 46 of Set 1 : awbari
# Processing Record 47 of Set 1 : karratha
# Processing Record 48 of Set 1 : yuci
# Processing Record 49 of Set 1 : sola
# Processing Record 50 of Set 1 : jiangkou
# Processing Record 0 of Set 2 : hithadhoo
# Processing Record 1 of Set 2 : kichera
# Processing Record 2 of Set 2 : genoa
# Processing Record 3 of Set 2 : carnarvon
# Processing Record 4 of Set 2 : mezen
# Processing Record 5 of Set 2 : busselton
# Processing Record 6 of Set 2 : mantua
# Processing Record 7 of Set 2 : jacareacanga
# Processing Record 8 of Set 2 : guerrero negro
# Processing Record 9 of Set 2 : provideniya
# Processing Record 10 of Set 2 : tiksi
# Processing Record 11 of Set 2 : hermanus
# Processing Record 12 of Set 2 : pueblo nuevo
# Processing Record 13 of Set 2 : asyut
# Processing Record 14 of Set 2 : chaman
# City not found. Looking for next value.
# Processing Record 15 of Set 2 : the valley
# Processing Record 16 of Set 2 : sitka
# Processing Record 17 of Set 2 : saskylakh
# Processing Record 18 of Set 2 : soto la marina
# Processing Record 19 of Set 2 : poya
# Processing Record 20 of Set 2 : albany
# Processing Record 21 of Set 2 : vaini
# City not found. Looking for next value.
# Processing Record 22 of Set 2 : valleyview
# City not found. Looking for next value.
# City not found. Looking for next value.
# City not found. Looking for next value.
# City not found. Looking for next value.
# City not found. Looking for next value.
# Processing Record 23 of Set 2 : rocha
# Processing Record 24 of Set 2 : tautira
# Processing Record 25 of Set 2 : teguldet
# Processing Record 26 of Set 2 : baraboo
# Processing Record 27 of Set 2 : bluff
# Processing Record 28 of Set 2 : saint anthony
# Processing Record 29 of Set 2 : souillac
# Processing Record 30 of Set 2 : danielskuil
# Processing Record 31 of Set 2 : bolitoc
# Processing Record 32 of Set 2 : ocean city
# Processing Record 33 of Set 2 : makat
# City not found. Looking for next value.
# Processing Record 34 of Set 2 : yabrud
# Processing Record 35 of Set 2 : maningrida
# City not found. Looking for next value.
# Processing Record 36 of Set 2 : petropavlovsk-kamchatskiy
# Processing Record 37 of Set 2 : arraial do cabo
# Processing Record 38 of Set 2 : jiaojiang
# Processing Record 39 of Set 2 : muros
# Processing Record 40 of Set 2 : cururupu
# Processing Record 41 of Set 2 : dikson
# Processing Record 42 of Set 2 : toamasina
# Processing Record 43 of Set 2 : longyearbyen
# Processing Record 44 of Set 2 : bredasdorp
# Processing Record 45 of Set 2 : khani
# Processing Record 46 of Set 2 : sao filipe
# Processing Record 47 of Set 2 : ushtobe
# Processing Record 48 of Set 2 : klyuchi
# Processing Record 49 of Set 2 : geraldton
# City not found. Looking for next value.
# City not found. Looking for next value.
# Processing Record 50 of Set 2 : nanortalik
# Processing Record 0 of Set 3 : valparaiso
# City not found. Looking for next value.
# Processing Record 1 of Set 3 : atuona
# Processing Record 2 of Set 3 : ancud
# Processing Record 3 of Set 3 : kosino
# Processing Record 4 of Set 3 : nikolayevsk-na-amure
# Processing Record 5 of Set 3 : haines junction
# Processing Record 6 of Set 3 : carutapera
# Processing Record 7 of Set 3 : belyy yar
# Processing Record 8 of Set 3 : killybegs
# Processing Record 9 of Set 3 : saint-georges
# City not found. Looking for next value.
# Processing Record 10 of Set 3 : riberalta
# Processing Record 11 of Set 3 : mar del plata
# Processing Record 12 of Set 3 : coquimbo
# Processing Record 13 of Set 3 : port hedland
# Processing Record 14 of Set 3 : zhigansk
# Processing Record 15 of Set 3 : oranjestad
# Processing Record 16 of Set 3 : celestun
# Processing Record 17 of Set 3 : ust-tsilma
# Processing Record 18 of Set 3 : bouafle
# Processing Record 19 of Set 3 : yellowknife
# Processing Record 20 of Set 3 : hofn
# Processing Record 21 of Set 3 : severo-kurilsk
# Processing Record 22 of Set 3 : kampene
# Processing Record 23 of Set 3 : maragogi
# Processing Record 24 of Set 3 : barrow
# Processing Record 25 of Set 3 : grindavik
# Processing Record 26 of Set 3 : chase
# City not found. Looking for next value.
# Processing Record 27 of Set 3 : myaundzha
# Processing Record 28 of Set 3 : den helder
# Processing Record 29 of Set 3 : batemans bay
# Processing Record 30 of Set 3 : port elizabeth
# Processing Record 31 of Set 3 : mackenzie
# Processing Record 32 of Set 3 : torbay
# Processing Record 33 of Set 3 : mvuma
# Processing Record 34 of Set 3 : katsuura
# Processing Record 35 of Set 3 : ekhabi
# Processing Record 36 of Set 3 : slovenske konjice
# Processing Record 37 of Set 3 : ponerihouen
# Processing Record 38 of Set 3 : kahului
# Processing Record 39 of Set 3 : djibo
# Processing Record 40 of Set 3 : egvekinot
# Processing Record 41 of Set 3 : honningsvag
# Processing Record 42 of Set 3 : nunoa
# Processing Record 43 of Set 3 : lata
# Processing Record 44 of Set 3 : kota tinggi
# Processing Record 45 of Set 3 : puerto del rosario
# Processing Record 46 of Set 3 : srednekolymsk
# Processing Record 47 of Set 3 : aklavik
# Processing Record 48 of Set 3 : codrington
# Processing Record 49 of Set 3 : madimba
# Processing Record 50 of Set 3 : bethel
# Processing Record 0 of Set 4 : axim
# Processing Record 1 of Set 4 : constitucion
# City not found. Looking for next value.
# Processing Record 2 of Set 4 : victoria
# Processing Record 3 of Set 4 : cabo san lucas
# Processing Record 4 of Set 4 : sioux lookout
# Processing Record 5 of Set 4 : vila velha
# Processing Record 6 of Set 4 : lazo
# Processing Record 7 of Set 4 : luderitz
# Processing Record 8 of Set 4 : birao
# Processing Record 9 of Set 4 : samoded
# City not found. Looking for next value.
# Processing Record 10 of Set 4 : corralillo
# Processing Record 11 of Set 4 : beloha
# Processing Record 12 of Set 4 : ingham
# Processing Record 13 of Set 4 : barcelos
# Processing Record 14 of Set 4 : lulea
# Processing Record 15 of Set 4 : camaqua
# Processing Record 16 of Set 4 : martinsburg
# Processing Record 17 of Set 4 : presidencia roque saenz pena
# Processing Record 18 of Set 4 : bandarbeyla
# Processing Record 19 of Set 4 : kupang
# Processing Record 20 of Set 4 : kennett
# Processing Record 21 of Set 4 : sept-iles
# Processing Record 22 of Set 4 : salta
# Processing Record 23 of Set 4 : kodiak
# Processing Record 24 of Set 4 : wuwei
# Processing Record 25 of Set 4 : mbini
# Processing Record 26 of Set 4 : norman wells
# Processing Record 27 of Set 4 : dalbandin
# Processing Record 28 of Set 4 : katherine
# Processing Record 29 of Set 4 : tyrma
# Processing Record 30 of Set 4 : masvingo
# Processing Record 31 of Set 4 : batagay
# Processing Record 32 of Set 4 : abu samrah
# Processing Record 33 of Set 4 : havre-saint-pierre
# Processing Record 34 of Set 4 : laguna
# Processing Record 35 of Set 4 : porto-vecchio
# Processing Record 36 of Set 4 : seoul
# Processing Record 37 of Set 4 : kalmunai
# Processing Record 38 of Set 4 : cidreira
# Processing Record 39 of Set 4 : saqqez
# Processing Record 40 of Set 4 : nakusp
# Processing Record 41 of Set 4 : brae
# Processing Record 42 of Set 4 : basco
# Processing Record 43 of Set 4 : rovaniemi
# Processing Record 44 of Set 4 : rayadrug
# Processing Record 45 of Set 4 : deputatskiy
# Processing Record 46 of Set 4 : micheweni
# Processing Record 47 of Set 4 : presidente venceslau
# Processing Record 48 of Set 4 : kavieng
# Processing Record 49 of Set 4 : ahipara
# Processing Record 50 of Set 4 : arandis
# Processing Record 0 of Set 5 : saldanha
# Processing Record 1 of Set 5 : leh
# Processing Record 2 of Set 5 : livingston
# Processing Record 3 of Set 5 : klaksvik
# Processing Record 4 of Set 5 : eirunepe
# Processing Record 5 of Set 5 : katobu
# Processing Record 6 of Set 5 : saint-pierre
# Processing Record 7 of Set 5 : dhariwal
# City not found. Looking for next value.
# Processing Record 8 of Set 5 : belaya gora
# Processing Record 9 of Set 5 : nambutalai
# Processing Record 10 of Set 5 : pietersburg
# Processing Record 11 of Set 5 : chunskiy
# Processing Record 12 of Set 5 : pevek
# Processing Record 13 of Set 5 : butaritari
# City not found. Looking for next value.
# Processing Record 14 of Set 5 : college
# Processing Record 15 of Set 5 : praia
# Processing Record 16 of Set 5 : akkermanovka
# Processing Record 17 of Set 5 : chekmagush
# Processing Record 18 of Set 5 : tacuati
# Processing Record 19 of Set 5 : kirakira
# Processing Record 20 of Set 5 : akureyri
# Processing Record 21 of Set 5 : monrovia
# Processing Record 22 of Set 5 : muroto
# Processing Record 23 of Set 5 : tanete
# Processing Record 24 of Set 5 : north augusta
# Processing Record 25 of Set 5 : yarim
# Processing Record 26 of Set 5 : cherskiy
# Processing Record 27 of Set 5 : goderich
# Processing Record 28 of Set 5 : point pleasant
# Processing Record 29 of Set 5 : mahebourg
# Processing Record 30 of Set 5 : tuatapere
# Processing Record 31 of Set 5 : abha
# City not found. Looking for next value.
# Processing Record 32 of Set 5 : mayo
# Processing Record 33 of Set 5 : half moon bay
# Processing Record 34 of Set 5 : caravelas
# Processing Record 35 of Set 5 : dalian
# City not found. Looking for next value.
# Processing Record 36 of Set 5 : mount gambier
# Processing Record 37 of Set 5 : aruja
# Processing Record 38 of Set 5 : hay river
# Processing Record 39 of Set 5 : zlobin
# Processing Record 40 of Set 5 : olafsvik
# City not found. Looking for next value.
# Processing Record 41 of Set 5 : morant bay
# Processing Record 42 of Set 5 : coxim
# City not found. Looking for next value.
# Processing Record 43 of Set 5 : coihaique
# Processing Record 44 of Set 5 : aloleng
# Processing Record 45 of Set 5 : kruisfontein
# Processing Record 46 of Set 5 : yambio
# Processing Record 47 of Set 5 : oytal
# City not found. Looking for next value.
# Processing Record 48 of Set 5 : shakawe
# City not found. Looking for next value.
# Processing Record 49 of Set 5 : chumikan
# Processing Record 50 of Set 5 : kieta
# Processing Record 0 of Set 6 : esperance
# Processing Record 1 of Set 6 : vostok
# Processing Record 2 of Set 6 : nalut
# Processing Record 3 of Set 6 : talcahuano
# Processing Record 4 of Set 6 : zunyi
# City not found. Looking for next value.
# Processing Record 5 of Set 6 : ponta do sol
# Processing Record 6 of Set 6 : koumac
# Processing Record 7 of Set 6 : nome
# Processing Record 8 of Set 6 : port moresby
# Processing Record 9 of Set 6 : lebu
# Processing Record 10 of Set 6 : mill valley
# Processing Record 11 of Set 6 : sorrento
# Processing Record 12 of Set 6 : srandakan
# Processing Record 13 of Set 6 : hot springs
# Processing Record 14 of Set 6 : georgetown
# Processing Record 15 of Set 6 : hualmay
# Processing Record 16 of Set 6 : missoula
# Processing Record 17 of Set 6 : grootfontein
# Processing Record 18 of Set 6 : lorengau
# Processing Record 19 of Set 6 : andenes
# Processing Record 20 of Set 6 : alice springs
# Processing Record 21 of Set 6 : mandalgovi
# Processing Record 22 of Set 6 : tulun
# Processing Record 23 of Set 6 : moussoro
# Processing Record 24 of Set 6 : marovoay
# Processing Record 25 of Set 6 : mahanoro
# Processing Record 26 of Set 6 : mae sai
# Processing Record 27 of Set 6 : wajima
# Processing Record 28 of Set 6 : lasa
# Processing Record 29 of Set 6 : zhaodong
# Processing Record 30 of Set 6 : isangel
# Processing Record 31 of Set 6 : atambua
# Processing Record 32 of Set 6 : shingu
# Processing Record 33 of Set 6 : shestakovo
# Processing Record 34 of Set 6 : vardo
# Processing Record 35 of Set 6 : bubaque
# Processing Record 36 of Set 6 : delta del tigre
# Processing Record 37 of Set 6 : yar-sale
# Processing Record 38 of Set 6 : alofi
# City not found. Looking for next value.
# Processing Record 39 of Set 6 : wote
# Processing Record 40 of Set 6 : statesville
# Processing Record 41 of Set 6 : flinders
# Processing Record 42 of Set 6 : vestmanna
# Processing Record 43 of Set 6 : cayenne
# Processing Record 44 of Set 6 : banda aceh
# Processing Record 45 of Set 6 : vila franca do campo
# Processing Record 46 of Set 6 : nabire
# Processing Record 47 of Set 6 : launceston
# Processing Record 48 of Set 6 : yantal
# Processing Record 49 of Set 6 : acajutla
# Processing Record 50 of Set 6 : san jorge
# City not found. Looking for next value.
# Processing Record 0 of Set 7 : alta floresta
# City not found. Looking for next value.
# Processing Record 1 of Set 7 : ormoz
# Processing Record 2 of Set 7 : pangody
# Processing Record 3 of Set 7 : magistralnyy
# Processing Record 4 of Set 7 : betare oya
# Processing Record 5 of Set 7 : vitim
# Processing Record 6 of Set 7 : horta
# Processing Record 7 of Set 7 : rincon
# Processing Record 8 of Set 7 : portland
# Processing Record 9 of Set 7 : christchurch
# Processing Record 10 of Set 7 : buraydah
# Processing Record 11 of Set 7 : oriximina
# Processing Record 12 of Set 7 : ovalle
# Processing Record 13 of Set 7 : tessalit
# Processing Record 14 of Set 7 : narsaq
# Processing Record 15 of Set 7 : pacific grove
# Processing Record 16 of Set 7 : candolim
# Processing Record 17 of Set 7 : bathsheba
# Processing Record 18 of Set 7 : sinegorskiy
# Processing Record 19 of Set 7 : manzanillo
# Processing Record 20 of Set 7 : necochea
# Processing Record 21 of Set 7 : cap malheureux
# Processing Record 22 of Set 7 : gejiu
# Processing Record 23 of Set 7 : keuruu
# Processing Record 24 of Set 7 : airai
# Processing Record 25 of Set 7 : penarroya-pueblonuevo
# Processing Record 26 of Set 7 : atar
# Processing Record 27 of Set 7 : bambanglipuro
# City not found. Looking for next value.
# Processing Record 28 of Set 7 : calvinia
# Processing Record 29 of Set 7 : dingle
# Processing Record 30 of Set 7 : pisco
# Processing Record 31 of Set 7 : ajdabiya
# Processing Record 32 of Set 7 : murgab
# Processing Record 33 of Set 7 : kandrian
# Processing Record 34 of Set 7 : nchelenge
# Processing Record 35 of Set 7 : okha
# Processing Record 36 of Set 7 : nouadhibou
# Processing Record 37 of Set 7 : bilibino
# Processing Record 38 of Set 7 : smoky lake
# Processing Record 39 of Set 7 : beringovskiy
# Processing Record 40 of Set 7 : hovd
# Processing Record 41 of Set 7 : lamu
# Processing Record 42 of Set 7 : vestmannaeyjar
# Processing Record 43 of Set 7 : fairbanks
# City not found. Looking for next value.
# Processing Record 44 of Set 7 : fort nelson
# Processing Record 45 of Set 7 : hambantota
# Processing Record 46 of Set 7 : machacamarca
# Processing Record 47 of Set 7 : leshukonskoye
# Processing Record 48 of Set 7 : grand gaube
# City not found. Looking for next value.
# Processing Record 49 of Set 7 : akyab
# Processing Record 50 of Set 7 : monterey
# Processing Record 0 of Set 8 : velen
# City not found. Looking for next value.
# Processing Record 1 of Set 8 : hirara
# Processing Record 2 of Set 8 : port lincoln
# Processing Record 3 of Set 8 : rawson
# Processing Record 4 of Set 8 : pangnirtung
# Processing Record 5 of Set 8 : eureka
# Processing Record 6 of Set 8 : youkounkoun
# Processing Record 7 of Set 8 : bardsir
# Processing Record 8 of Set 8 : qaqortoq
# Processing Record 9 of Set 8 : port augusta
# Processing Record 10 of Set 8 : cine
# Processing Record 11 of Set 8 : bestobe
# Processing Record 12 of Set 8 : pidhaytsi
# Processing Record 13 of Set 8 : margate
# Processing Record 14 of Set 8 : sakaiminato
# Processing Record 15 of Set 8 : honiara
# Processing Record 16 of Set 8 : sosnovo-ozerskoye
# Processing Record 17 of Set 8 : buala
# Processing Record 18 of Set 8 : nemuro
# Processing Record 19 of Set 8 : la malbaie
# Processing Record 20 of Set 8 : kushmurun
# City not found. Looking for next value.
# Processing Record 21 of Set 8 : nizwa
# Processing Record 22 of Set 8 : abasolo
# Processing Record 23 of Set 8 : praxedis guerrero
# Processing Record 24 of Set 8 : qui nhon
# Processing Record 25 of Set 8 : kawalu
# Processing Record 26 of Set 8 : takoradi
# City not found. Looking for next value.
# Processing Record 27 of Set 8 : mackay
# Processing Record 28 of Set 8 : ivdel
# Processing Record 29 of Set 8 : pilar
# Processing Record 30 of Set 8 : najran
# Processing Record 31 of Set 8 : boden
# Processing Record 32 of Set 8 : ostrovnoy
# Processing Record 33 of Set 8 : bonfim
# Processing Record 34 of Set 8 : san quintin
# Processing Record 35 of Set 8 : giaveno
# City not found. Looking for next value.
# Processing Record 36 of Set 8 : howard springs
# Processing Record 37 of Set 8 : luwuk
# Processing Record 38 of Set 8 : huarmey
# Processing Record 39 of Set 8 : zhuhai
# Processing Record 40 of Set 8 : eustis
# Processing Record 41 of Set 8 : el cobre
# Processing Record 42 of Set 8 : erzin
# Processing Record 43 of Set 8 : praia da vitoria
# Processing Record 44 of Set 8 : dongsheng
# Processing Record 45 of Set 8 : marti
# Processing Record 46 of Set 8 : jiuquan
# Processing Record 47 of Set 8 : ginda
# Processing Record 48 of Set 8 : pachino
# Processing Record 49 of Set 8 : miraflores
# City not found. Looking for next value.
# Processing Record 50 of Set 8 : oranjemund
# Processing Record 0 of Set 9 : chotila
# Processing Record 1 of Set 9 : suntar
# Processing Record 2 of Set 9 : acarau
# Processing Record 3 of Set 9 : beipiao
# Processing Record 4 of Set 9 : lima
# Processing Record 5 of Set 9 : gumdag
# Processing Record 6 of Set 9 : makakilo city
# Processing Record 7 of Set 9 : catuday
# Processing Record 8 of Set 9 : champerico
# Processing Record 9 of Set 9 : menongue
# Processing Record 10 of Set 9 : thompson
# Processing Record 11 of Set 9 : antalaha
# Processing Record 12 of Set 9 : taoudenni
# Processing Record 13 of Set 9 : sindor
# Processing Record 14 of Set 9 : barranca
# City not found. Looking for next value.
# City not found. Looking for next value.
# Processing Record 15 of Set 9 : mabaruma
# Processing Record 16 of Set 9 : araouane
# Processing Record 17 of Set 9 : lavrentiya
# Processing Record 18 of Set 9 : okitipupa
# Processing Record 19 of Set 9 : mogadishu
# Processing Record 20 of Set 9 : ilulissat
# Processing Record 21 of Set 9 : omsukchan
# Processing Record 22 of Set 9 : saint augustine
# Processing Record 23 of Set 9 : port hardy
# Processing Record 24 of Set 9 : lyubar
# Processing Record 25 of Set 9 : visp
# Processing Record 26 of Set 9 : buchanan
# Processing Record 27 of Set 9 : mandurah
# Processing Record 28 of Set 9 : kirkwall
# Processing Record 29 of Set 9 : vacaria
# Processing Record 30 of Set 9 : anadyr
# Processing Record 31 of Set 9 : tongren
# Processing Record 32 of Set 9 : chake chake
# Processing Record 33 of Set 9 : quatre cocos
# Processing Record 34 of Set 9 : bowmore
# Processing Record 35 of Set 9 : boa vista
# City not found. Looking for next value.
# Processing Record 36 of Set 9 : salinopolis
# Processing Record 37 of Set 9 : koltsovo
# Processing Record 38 of Set 9 : yumen
# Processing Record 39 of Set 9 : yulara
# Processing Record 40 of Set 9 : saint-augustin
# Processing Record 41 of Set 9 : marawi
# Processing Record 42 of Set 9 : saint-michel-des-saints
# Processing Record 43 of Set 9 : lompoc
# Processing Record 44 of Set 9 : matagami
# Processing Record 45 of Set 9 : korla
# Processing Record 46 of Set 9 : anaco
# City not found. Looking for next value.
# Processing Record 47 of Set 9 : waddan
# Processing Record 48 of Set 9 : sangin
# Processing Record 49 of Set 9 : shyroke
# Processing Record 50 of Set 9 : chuy
# Processing Record 0 of Set 10 : amapa
# Processing Record 1 of Set 10 : aykhal
# Processing Record 2 of Set 10 : ous
# City not found. Looking for next value.
# Processing Record 3 of Set 10 : tiarei
# Processing Record 4 of Set 10 : turukhansk
# Processing Record 5 of Set 10 : te anau
# Processing Record 6 of Set 10 : tibati
# Processing Record 7 of Set 10 : sabha
# Processing Record 8 of Set 10 : avesta
# Processing Record 9 of Set 10 : crotone
# Processing Record 10 of Set 10 : puerto ayacucho
# Processing Record 11 of Set 10 : sorong
# Processing Record 12 of Set 10 : kyabe
# Processing Record 13 of Set 10 : olenegorsk
# Processing Record 14 of Set 10 : borkenes
# Processing Record 15 of Set 10 : sao miguel do araguaia
# Processing Record 16 of Set 10 : harper
# City not found. Looking for next value.
# Processing Record 17 of Set 10 : husavik
# Processing Record 18 of Set 10 : palmer
# Processing Record 19 of Set 10 : pokosnoye
# Processing Record 20 of Set 10 : huron
# City not found. Looking for next value.
# Processing Record 21 of Set 10 : komatipoort
# City not found. Looking for next value.
# Processing Record 22 of Set 10 : jardim
# Processing Record 23 of Set 10 : twin falls
# Processing Record 24 of Set 10 : villazon
# Processing Record 25 of Set 10 : salalah
# Processing Record 26 of Set 10 : ulaangom
# Processing Record 27 of Set 10 : hamilton
# Processing Record 28 of Set 10 : teacapan
# Processing Record 29 of Set 10 : hudiksvall
# Processing Record 30 of Set 10 : thohoyandou
# Processing Record 31 of Set 10 : cacequi
# Processing Record 32 of Set 10 : pozo colorado
# Processing Record 33 of Set 10 : taldan
# Processing Record 34 of Set 10 : kimbe
# Processing Record 35 of Set 10 : tura
# Processing Record 36 of Set 10 : bacolod
# Processing Record 37 of Set 10 : darhan
# Processing Record 38 of Set 10 : kulhudhuffushi
# Processing Record 39 of Set 10 : deep river
# City not found. Looking for next value.
# Processing Record 40 of Set 10 : itoman
# Processing Record 41 of Set 10 : wonthaggi
# Processing Record 42 of Set 10 : san vicente
# Processing Record 43 of Set 10 : cockburn town
# Processing Record 44 of Set 10 : sotouboua
# Processing Record 45 of Set 10 : noshiro
# Processing Record 46 of Set 10 : mtwango
# Processing Record 47 of Set 10 : asau
# Processing Record 48 of Set 10 : puerto colombia
# Processing Record 49 of Set 10 : daru
# Processing Record 50 of Set 10 : bethanien
# Processing Record 0 of Set 11 : mazamet
# Processing Record 1 of Set 11 : chapais
# Processing Record 2 of Set 11 : lakes entrance
# Processing Record 3 of Set 11 : meulaboh
# Processing Record 4 of Set 11 : robertsonpet
# City not found. Looking for next value.
# Processing Record 5 of Set 11 : duku
# Processing Record 6 of Set 11 : marsabit
# Processing Record 7 of Set 11 : talnakh
# Processing Record 8 of Set 11 : pimentel
# Processing Record 9 of Set 11 : inuvik
# Processing Record 10 of Set 11 : san andres
# Processing Record 11 of Set 11 : verkhnechusovskiye gorodki
# Processing Record 12 of Set 11 : victoria point
# Processing Record 13 of Set 11 : sulangan
# Processing Record 14 of Set 11 : beira
# City not found. Looking for next value.
# Processing Record 15 of Set 11 : paidha
# Processing Record 16 of Set 11 : progreso
# Processing Record 17 of Set 11 : fortuna
# City not found. Looking for next value.
# Processing Record 18 of Set 11 : bud
# Processing Record 19 of Set 11 : jardim do serido
# Processing Record 20 of Set 11 : moron
# Processing Record 21 of Set 11 : nsoko
# Processing Record 22 of Set 11 : sumkino
# Processing Record 23 of Set 11 : port-gentil
# Processing Record 24 of Set 11 : aquiraz
# Processing Record 25 of Set 11 : bata
# Processing Record 26 of Set 11 : barguzin
# Processing Record 27 of Set 11 : canon city
# Processing Record 28 of Set 11 : kenai
# Processing Record 29 of Set 11 : thaba-tseka
# Processing Record 30 of Set 11 : hami
# Processing Record 31 of Set 11 : cascais
# Processing Record 32 of Set 11 : cedar city
# Processing Record 33 of Set 11 : skjervoy
# Processing Record 34 of Set 11 : manta
# Processing Record 35 of Set 11 : lazaro cardenas
# Processing Record 36 of Set 11 : warrington
# Processing Record 37 of Set 11 : west bay
# Processing Record 38 of Set 11 : javanrud
# Processing Record 39 of Set 11 : semiletka
# Processing Record 40 of Set 11 : bolanos de calatrava
# Processing Record 41 of Set 11 : kirensk
# Processing Record 42 of Set 11 : vanavara
# Processing Record 43 of Set 11 : forestville
# Processing Record 44 of Set 11 : mananjary
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame using data from above code by creating a dict
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

#count data above
weather_dict.count()
# Out:
# City          554
# Cloudiness    554
# Country       554
# Date          554
# Humidity      554
# Lat           554
# Lng           554
# Max Temp      554
# Wind Speed    554
# dtype: int64

# %%
#view data frame
weather_dict
# Out:
#                      City  Cloudiness Country        Date  Humidity    Lat  \
# 0                    Goba          35      ET  1603173420        64   7.02
# 1        Coahuayana Viejo          82      MX  1603173420        89  18.73
# 2                  Hasaki          20      JP  1603173015        60  35.73
# 3                Khatanga          84      RU  1603172952        96  71.97
# 4                Tasiilaq          90      GL  1603172960       100  65.61
# ..                    ...         ...     ...         ...       ...    ...
# 549  Bolaños de Calatrava         100      ES  1603173531        40  38.91
# 550               Kirensk          99      RU  1603173531        91  57.79
# 551              Vanavara         100      RU  1603173207        92  60.34
# 552           Forestville           1      US  1603173531        93  38.85
# 553             Mananjary          14      MG  1603173532        62 -21.22
#
#         Lng  Max Temp  Wind Speed
# 0     39.98     55.92        4.52
# 1   -103.68     78.17        1.99
# 2    140.83     72.00       11.41
# 3    102.50     12.33        6.78
# 4    -37.64     28.40        6.93
# ..      ...       ...         ...
# 549   -3.66     68.00       10.29
# 550  108.11     29.39       12.21
# 551  102.28     27.39       12.82
# 552  -76.88     61.00        3.31
# 553   48.33     77.92        4.92
#
# [554 rows x 9 columns]

# %%
#Create output file into a csv file
weather_dict.to_csv("../WeatherPy/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#There were no records with humidity > 100% - SKIPPING

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "red", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (10/19/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "yellow", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (10/19/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "orange", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (10/19/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "green", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (10/19/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# Create DataFrames for both north and south hemi
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
#Creating linear agression and scatter plot - use define function
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

#Define function for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call on linear_regression
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
# Call on annotation
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.89

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.66

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.26

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.07

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.27

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.13

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.17
