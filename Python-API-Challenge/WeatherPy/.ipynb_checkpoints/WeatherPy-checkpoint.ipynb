# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you
# think through the steps.
#
# Observations:
# * As latitude increases, the trend appears to show a decrease in max temperature in the Northern Hemisphere.
# * There is a strong negative correlation between latitude and the max temperature in the northern hemisphere.
# * There is a very weak positive correlation between latitude and cloudiness for the souther hemisphere.

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import weather API key
from api_keys import weather_api_key

# Getting city date - using long and lat
from citipy import citipy

# Output File (CSV)
output_data_file = "WeatherPy/cities.csv"

#Setting range for lat and long
lat_range = (-90, 90)
long_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Creating variables to store lat and long combos and also creating variable to store cities
lat_long_rand = []
cities = []

# Create a set of random lat and lng combinations
latitude_rand = np.random.uniform(low=-90.000, high=90.000, size=1500)
longitude_rand = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_long_rand = zip(latitude_rand, longitude_rand)

# Identify nearest city for each lat long combo generated
for lat_long in lat_long_rand:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    
    # If the city is unique, then add it to list of cities
    if city not in cities:
        cities.append(city)

# Print count to confirm working code
len(cities)
# Out:
# 635

# %%
# Creating lists to store values

city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Looking for next value.")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : berlin
# Processing Record 2 of Set 1 : tasiilaq
# Processing Record 3 of Set 1 : bambous virieux
# Processing Record 4 of Set 1 : yumen
# Processing Record 5 of Set 1 : vila franca do campo
# Processing Record 6 of Set 1 : mahebourg
# City not found. Looking for next value.
# Processing Record 7 of Set 1 : saskylakh
# Processing Record 8 of Set 1 : vaini
# Processing Record 9 of Set 1 : georgetown
# Processing Record 10 of Set 1 : rikitea
# Processing Record 11 of Set 1 : vestmanna
# Processing Record 12 of Set 1 : lodja
# Processing Record 13 of Set 1 : kodiak
# Processing Record 14 of Set 1 : hobart
# Processing Record 15 of Set 1 : narsaq
# Processing Record 16 of Set 1 : yellowknife
# Processing Record 17 of Set 1 : lebu
# Processing Record 18 of Set 1 : punta arenas
# Processing Record 19 of Set 1 : clyde river
# Processing Record 20 of Set 1 : dzilam gonzalez
# Processing Record 21 of Set 1 : mataura
# City not found. Looking for next value.
# Processing Record 22 of Set 1 : coshocton
# Processing Record 23 of Set 1 : vazante
# Processing Record 24 of Set 1 : lisala
# Processing Record 25 of Set 1 : hasaki
# Processing Record 26 of Set 1 : herat
# Processing Record 27 of Set 1 : atar
# Processing Record 28 of Set 1 : saint-pierre
# Processing Record 29 of Set 1 : xining
# Processing Record 30 of Set 1 : yerbogachen
# Processing Record 31 of Set 1 : provideniya
# Processing Record 32 of Set 1 : husavik
# City not found. Looking for next value.
# Processing Record 33 of Set 1 : saint-philippe
# Processing Record 34 of Set 1 : arraial do cabo
# Processing Record 35 of Set 1 : margate
# Processing Record 36 of Set 1 : codrington
# Processing Record 37 of Set 1 : sioux lookout
# Processing Record 38 of Set 1 : ambunti
# Processing Record 39 of Set 1 : kapaa
# City not found. Looking for next value.
# Processing Record 40 of Set 1 : tiksi
# Processing Record 41 of Set 1 : lompoc
# Processing Record 42 of Set 1 : new norfolk
# Processing Record 43 of Set 1 : tumut
# City not found. Looking for next value.
# Processing Record 44 of Set 1 : temple
# City not found. Looking for next value.
# Processing Record 45 of Set 1 : marsa matruh
# Processing Record 46 of Set 1 : gaoual
# Processing Record 47 of Set 1 : cape town
# Processing Record 48 of Set 1 : seymchan
# City not found. Looking for next value.
# Processing Record 49 of Set 1 : sao jose da coroa grande
# Processing Record 50 of Set 1 : qaanaaq
# City not found. Looking for next value.
# Processing Record 0 of Set 2 : butaritari
# Processing Record 1 of Set 2 : karlskoga
# Processing Record 2 of Set 2 : twante
# Processing Record 3 of Set 2 : port elizabeth
# Processing Record 4 of Set 2 : yima
# Processing Record 5 of Set 2 : lagoa
# Processing Record 6 of Set 2 : albany
# Processing Record 7 of Set 2 : hilo
# City not found. Looking for next value.
# Processing Record 8 of Set 2 : yarada
# Processing Record 9 of Set 2 : ushuaia
# Processing Record 10 of Set 2 : bonavista
# Processing Record 11 of Set 2 : poso
# Processing Record 12 of Set 2 : mgachi
# Processing Record 13 of Set 2 : beruwala
# Processing Record 14 of Set 2 : ruwi
# Processing Record 15 of Set 2 : bahia honda
# Processing Record 16 of Set 2 : khatanga
# Processing Record 17 of Set 2 : rocha
# City not found. Looking for next value.
# Processing Record 18 of Set 2 : barrow
# Processing Record 19 of Set 2 : atuona
# Processing Record 20 of Set 2 : thompson
# Processing Record 21 of Set 2 : bilibino
# Processing Record 22 of Set 2 : berlevag
# Processing Record 23 of Set 2 : alofi
# Processing Record 24 of Set 2 : lerwick
# Processing Record 25 of Set 2 : arbazh
# Processing Record 26 of Set 2 : carnarvon
# Processing Record 27 of Set 2 : bluff
# Processing Record 28 of Set 2 : byron bay
# Processing Record 29 of Set 2 : avarua
# Processing Record 30 of Set 2 : piacabucu
# Processing Record 31 of Set 2 : kieta
# Processing Record 32 of Set 2 : busselton
# Processing Record 33 of Set 2 : katsuura
# Processing Record 34 of Set 2 : price
# Processing Record 35 of Set 2 : vardo
# Processing Record 36 of Set 2 : jamestown
# Processing Record 37 of Set 2 : puerto ayora
# Processing Record 38 of Set 2 : klaksvik
# Processing Record 39 of Set 2 : mehamn
# Processing Record 40 of Set 2 : laguna
# Processing Record 41 of Set 2 : marystown
# Processing Record 42 of Set 2 : esmeralda
# Processing Record 43 of Set 2 : ulladulla
# Processing Record 44 of Set 2 : ozu
# Processing Record 45 of Set 2 : nezhinka
# Processing Record 46 of Set 2 : rudsar
# Processing Record 47 of Set 2 : kaeo
# Processing Record 48 of Set 2 : dingle
# Processing Record 49 of Set 2 : severo-kurilsk
# Processing Record 50 of Set 2 : holbeach
# Processing Record 0 of Set 3 : mayo
# Processing Record 1 of Set 3 : san cristobal
# Processing Record 2 of Set 3 : victoria
# City not found. Looking for next value.
# Processing Record 3 of Set 3 : inirida
# Processing Record 4 of Set 3 : high level
# Processing Record 5 of Set 3 : alghero
# Processing Record 6 of Set 3 : hermanus
# Processing Record 7 of Set 3 : vavuniya
# Processing Record 8 of Set 3 : fuerte olimpo
# Processing Record 9 of Set 3 : abha
# Processing Record 10 of Set 3 : northam
# Processing Record 11 of Set 3 : fort nelson
# Processing Record 12 of Set 3 : bouake
# Processing Record 13 of Set 3 : anori
# Processing Record 14 of Set 3 : nome
# Processing Record 15 of Set 3 : pacific grove
# Processing Record 16 of Set 3 : burns lake
# Processing Record 17 of Set 3 : east london
# Processing Record 18 of Set 3 : zhanaozen
# Processing Record 19 of Set 3 : florianopolis
# Processing Record 20 of Set 3 : hovd
# Processing Record 21 of Set 3 : sao filipe
# Processing Record 22 of Set 3 : kaitangata
# Processing Record 23 of Set 3 : plouzane
# Processing Record 24 of Set 3 : sur
# Processing Record 25 of Set 3 : rawson
# Processing Record 26 of Set 3 : bilma
# Processing Record 27 of Set 3 : hithadhoo
# Processing Record 28 of Set 3 : petropavlovsk-kamchatskiy
# Processing Record 29 of Set 3 : sal rei
# Processing Record 30 of Set 3 : mayumba
# Processing Record 31 of Set 3 : dickinson
# Processing Record 32 of Set 3 : alyangula
# Processing Record 33 of Set 3 : mount gambier
# Processing Record 34 of Set 3 : broome
# Processing Record 35 of Set 3 : pevek
# Processing Record 36 of Set 3 : waddan
# Processing Record 37 of Set 3 : north bend
# Processing Record 38 of Set 3 : khani
# Processing Record 39 of Set 3 : camana
# Processing Record 40 of Set 3 : bredasdorp
# Processing Record 41 of Set 3 : tezu
# Processing Record 42 of Set 3 : mar del plata
# Processing Record 43 of Set 3 : dubai
# Processing Record 44 of Set 3 : mount isa
# Processing Record 45 of Set 3 : beloha
# Processing Record 46 of Set 3 : chabahar
# Processing Record 47 of Set 3 : hamilton
# Processing Record 48 of Set 3 : vostok
# Processing Record 49 of Set 3 : erzin
# Processing Record 50 of Set 3 : careiro da varzea
# City not found. Looking for next value.
# Processing Record 0 of Set 4 : sinnamary
# Processing Record 1 of Set 4 : isangel
# Processing Record 2 of Set 4 : gornopravdinsk
# Processing Record 3 of Set 4 : ponta delgada
# Processing Record 4 of Set 4 : omagari
# City not found. Looking for next value.
# Processing Record 5 of Set 4 : krasnoselkup
# Processing Record 6 of Set 4 : ponta do sol
# Processing Record 7 of Set 4 : xinzhi
# Processing Record 8 of Set 4 : port keats
# City not found. Looking for next value.
# Processing Record 9 of Set 4 : obo
# Processing Record 10 of Set 4 : souillac
# City not found. Looking for next value.
# City not found. Looking for next value.
# Processing Record 11 of Set 4 : khirkiya
# Processing Record 12 of Set 4 : itarema
# Processing Record 13 of Set 4 : nanortalik
# Processing Record 14 of Set 4 : sefophe
# Processing Record 15 of Set 4 : grindavik
# Processing Record 16 of Set 4 : bengkulu
# Processing Record 17 of Set 4 : upernavik
# Processing Record 18 of Set 4 : torbay
# Processing Record 19 of Set 4 : cidreira
# Processing Record 20 of Set 4 : frumusita
# Processing Record 21 of Set 4 : saldanha
# Processing Record 22 of Set 4 : huron
# Processing Record 23 of Set 4 : bereznik
# Processing Record 24 of Set 4 : san quintin
# Processing Record 25 of Set 4 : chuy
# Processing Record 26 of Set 4 : tuktoyaktuk
# Processing Record 27 of Set 4 : bull savanna
# Processing Record 28 of Set 4 : aklavik
# Processing Record 29 of Set 4 : cartagena
# Processing Record 30 of Set 4 : mana
# Processing Record 31 of Set 4 : ostrovnoy
# Processing Record 32 of Set 4 : oksfjord
# Processing Record 33 of Set 4 : geraldton
# Processing Record 34 of Set 4 : naraina
# Processing Record 35 of Set 4 : marfino
# Processing Record 36 of Set 4 : maniitsoq
# Processing Record 37 of Set 4 : dolores
# Processing Record 38 of Set 4 : kostyantynivka
# Processing Record 39 of Set 4 : necochea
# Processing Record 40 of Set 4 : swan hill
# Processing Record 41 of Set 4 : lavrentiya
# Processing Record 42 of Set 4 : tomatlan
# Processing Record 43 of Set 4 : leeton
# Processing Record 44 of Set 4 : pochutla
# Processing Record 45 of Set 4 : guarapuava
# Processing Record 46 of Set 4 : taltal
# Processing Record 47 of Set 4 : bethel
# Processing Record 48 of Set 4 : soyo
# Processing Record 49 of Set 4 : constitucion
# Processing Record 50 of Set 4 : leningradskiy
# Processing Record 0 of Set 5 : czestochowa
# Processing Record 1 of Set 5 : visby
# Processing Record 2 of Set 5 : pisco
# Processing Record 3 of Set 5 : noyabrsk
# Processing Record 4 of Set 5 : san patricio
# Processing Record 5 of Set 5 : choma
# Processing Record 6 of Set 5 : kalmunai
# Processing Record 7 of Set 5 : usinsk
# Processing Record 8 of Set 5 : half moon bay
# Processing Record 9 of Set 5 : cherskiy
# Processing Record 10 of Set 5 : zhezkazgan
# Processing Record 11 of Set 5 : san francisco
# Processing Record 12 of Set 5 : makakilo city
# Processing Record 13 of Set 5 : edd
# Processing Record 14 of Set 5 : revelstoke
# Processing Record 15 of Set 5 : ankazoabo
# Processing Record 16 of Set 5 : diphu
# Processing Record 17 of Set 5 : linqing
# Processing Record 18 of Set 5 : komsomolskiy
# Processing Record 19 of Set 5 : nosy varika
# Processing Record 20 of Set 5 : labu-o
# Processing Record 21 of Set 5 : polunochnoye
# Processing Record 22 of Set 5 : qasigiannguit
# Processing Record 23 of Set 5 : uarini
# Processing Record 24 of Set 5 : itinga
# Processing Record 25 of Set 5 : atbasar
# Processing Record 26 of Set 5 : richards bay
# Processing Record 27 of Set 5 : never
# Processing Record 28 of Set 5 : bambanglipuro
# Processing Record 29 of Set 5 : atlantis
# Processing Record 30 of Set 5 : hualmay
# Processing Record 31 of Set 5 : nabire
# Processing Record 32 of Set 5 : santa vitoria do palmar
# Processing Record 33 of Set 5 : salta
# Processing Record 34 of Set 5 : tessalit
# Processing Record 35 of Set 5 : ugoofaaru
# Processing Record 36 of Set 5 : nicoya
# Processing Record 37 of Set 5 : sao joao da barra
# Processing Record 38 of Set 5 : zelenoborskiy
# Processing Record 39 of Set 5 : sitka
# Processing Record 40 of Set 5 : puerto santander
# Processing Record 41 of Set 5 : abingdon
# Processing Record 42 of Set 5 : faanui
# Processing Record 43 of Set 5 : acapulco
# Processing Record 44 of Set 5 : skjervoy
# Processing Record 45 of Set 5 : newport
# Processing Record 46 of Set 5 : sabha
# Processing Record 47 of Set 5 : bandarbeyla
# Processing Record 48 of Set 5 : kavaratti
# Processing Record 49 of Set 5 : passos
# Processing Record 50 of Set 5 : karratha
# Processing Record 0 of Set 6 : aripuana
# Processing Record 1 of Set 6 : koumac
# Processing Record 2 of Set 6 : kyra
# Processing Record 3 of Set 6 : yulara
# Processing Record 4 of Set 6 : ati
# Processing Record 5 of Set 6 : tahoua
# Processing Record 6 of Set 6 : antalaha
# Processing Record 7 of Set 6 : dwarka
# Processing Record 8 of Set 6 : hit
# Processing Record 9 of Set 6 : reporoa
# Processing Record 10 of Set 6 : kokopo
# Processing Record 11 of Set 6 : centerville
# Processing Record 12 of Set 6 : luwuk
# Processing Record 13 of Set 6 : iqaluit
# Processing Record 14 of Set 6 : ambilobe
# Processing Record 15 of Set 6 : esmeraldas
# Processing Record 16 of Set 6 : westport
# Processing Record 17 of Set 6 : carutapera
# Processing Record 18 of Set 6 : bay roberts
# Processing Record 19 of Set 6 : boulder
# City not found. Looking for next value.
# Processing Record 20 of Set 6 : talnakh
# Processing Record 21 of Set 6 : acajutla
# City not found. Looking for next value.
# Processing Record 22 of Set 6 : slonim
# Processing Record 23 of Set 6 : deputatskiy
# Processing Record 24 of Set 6 : damghan
# Processing Record 25 of Set 6 : zhigansk
# Processing Record 26 of Set 6 : merauke
# Processing Record 27 of Set 6 : katangli
# Processing Record 28 of Set 6 : kichera
# Processing Record 29 of Set 6 : presidencia roque saenz pena
# Processing Record 30 of Set 6 : hofn
# Processing Record 31 of Set 6 : ribeira grande
# Processing Record 32 of Set 6 : qaqortoq
# Processing Record 33 of Set 6 : pando
# Processing Record 34 of Set 6 : harbour breton
# Processing Record 35 of Set 6 : wanning
# Processing Record 36 of Set 6 : oranjestad
# Processing Record 37 of Set 6 : seoul
# Processing Record 38 of Set 6 : welkom
# City not found. Looking for next value.
# Processing Record 39 of Set 6 : ramgarh
# Processing Record 40 of Set 6 : port blair
# Processing Record 41 of Set 6 : estacion coahuila
# Processing Record 42 of Set 6 : brigantine
# Processing Record 43 of Set 6 : verkh-suetka
# Processing Record 44 of Set 6 : tazovskiy
# Processing Record 45 of Set 6 : castro
# City not found. Looking for next value.
# Processing Record 46 of Set 6 : kontagora
# Processing Record 47 of Set 6 : sola
# Processing Record 48 of Set 6 : doha
# Processing Record 49 of Set 6 : mangrol
# Processing Record 50 of Set 6 : ellisras
# Processing Record 0 of Set 7 : george
# Processing Record 1 of Set 7 : tete
# Processing Record 2 of Set 7 : dombarovskiy
# Processing Record 3 of Set 7 : sindou
# Processing Record 4 of Set 7 : xinqing
# Processing Record 5 of Set 7 : chilia veche
# City not found. Looking for next value.
# Processing Record 6 of Set 7 : chokurdakh
# Processing Record 7 of Set 7 : porto novo
# Processing Record 8 of Set 7 : tabory
# Processing Record 9 of Set 7 : norman wells
# Processing Record 10 of Set 7 : suntar
# Processing Record 11 of Set 7 : muros
# City not found. Looking for next value.
# Processing Record 12 of Set 7 : brae
# Processing Record 13 of Set 7 : bitkine
# Processing Record 14 of Set 7 : saint george
# Processing Record 15 of Set 7 : gweru
# Processing Record 16 of Set 7 : alice springs
# Processing Record 17 of Set 7 : yeppoon
# City not found. Looking for next value.
# Processing Record 18 of Set 7 : hammerfest
# Processing Record 19 of Set 7 : port pirie
# Processing Record 20 of Set 7 : yuli
# Processing Record 21 of Set 7 : la ronge
# Processing Record 22 of Set 7 : iskateley
# Processing Record 23 of Set 7 : lake city
# Processing Record 24 of Set 7 : dassel
# Processing Record 25 of Set 7 : kavieng
# City not found. Looking for next value.
# Processing Record 26 of Set 7 : dejen
# City not found. Looking for next value.
# Processing Record 27 of Set 7 : laon
# Processing Record 28 of Set 7 : cabo san lucas
# Processing Record 29 of Set 7 : santa fe
# Processing Record 30 of Set 7 : nadym
# Processing Record 31 of Set 7 : morant bay
# Processing Record 32 of Set 7 : concordia
# Processing Record 33 of Set 7 : najran
# Processing Record 34 of Set 7 : niamey
# Processing Record 35 of Set 7 : roald
# Processing Record 36 of Set 7 : karavayevo
# Processing Record 37 of Set 7 : talara
# Processing Record 38 of Set 7 : usoke
# Processing Record 39 of Set 7 : kahului
# Processing Record 40 of Set 7 : labuhan
# Processing Record 41 of Set 7 : fairbanks
# Processing Record 42 of Set 7 : pontes e lacerda
# Processing Record 43 of Set 7 : skelleftea
# Processing Record 44 of Set 7 : gravdal
# Processing Record 45 of Set 7 : lubango
# Processing Record 46 of Set 7 : cockburn town
# Processing Record 47 of Set 7 : naze
# Processing Record 48 of Set 7 : hervey bay
# Processing Record 49 of Set 7 : cururupu
# Processing Record 50 of Set 7 : iquique
# Processing Record 0 of Set 8 : airai
# Processing Record 1 of Set 8 : santarem
# Processing Record 2 of Set 8 : baykit
# Processing Record 3 of Set 8 : nampa
# Processing Record 4 of Set 8 : vao
# Processing Record 5 of Set 8 : pathein
# Processing Record 6 of Set 8 : eyrarbakki
# Processing Record 7 of Set 8 : lander
# Processing Record 8 of Set 8 : omboue
# City not found. Looking for next value.
# Processing Record 9 of Set 8 : pocoes
# Processing Record 10 of Set 8 : colinas
# Processing Record 11 of Set 8 : kochevo
# Processing Record 12 of Set 8 : vetlanda
# Processing Record 13 of Set 8 : dikson
# Processing Record 14 of Set 8 : rovaniemi
# City not found. Looking for next value.
# Processing Record 15 of Set 8 : olivenza
# Processing Record 16 of Set 8 : port hardy
# Processing Record 17 of Set 8 : vila velha
# Processing Record 18 of Set 8 : goderich
# Processing Record 19 of Set 8 : nikolskoye
# Processing Record 20 of Set 8 : taveta
# Processing Record 21 of Set 8 : mandla
# Processing Record 22 of Set 8 : ancud
# Processing Record 23 of Set 8 : kavos
# Processing Record 24 of Set 8 : anadyr
# Processing Record 25 of Set 8 : bourail
# Processing Record 26 of Set 8 : taoudenni
# Processing Record 27 of Set 8 : khandyga
# Processing Record 28 of Set 8 : loikaw
# Processing Record 29 of Set 8 : parfino
# Processing Record 30 of Set 8 : lasa
# Processing Record 31 of Set 8 : sydney
# Processing Record 32 of Set 8 : mahibadhoo
# Processing Record 33 of Set 8 : angoche
# Processing Record 34 of Set 8 : cardston
# Processing Record 35 of Set 8 : epe
# Processing Record 36 of Set 8 : caravelas
# Processing Record 37 of Set 8 : ghanzi
# Processing Record 38 of Set 8 : chifeng
# Processing Record 39 of Set 8 : esik
# Processing Record 40 of Set 8 : tuatapere
# Processing Record 41 of Set 8 : saraza
# Processing Record 42 of Set 8 : pinega
# City not found. Looking for next value.
# Processing Record 43 of Set 8 : rio gallegos
# Processing Record 44 of Set 8 : mpraeso
# Processing Record 45 of Set 8 : lae
# Processing Record 46 of Set 8 : pangnirtung
# Processing Record 47 of Set 8 : teknaf
# Processing Record 48 of Set 8 : mozarlandia
# Processing Record 49 of Set 8 : kruisfontein
# Processing Record 50 of Set 8 : kehtna
# City not found. Looking for next value.
# Processing Record 0 of Set 9 : los llanos de aridane
# Processing Record 1 of Set 9 : ginir
# Processing Record 2 of Set 9 : hailar
# Processing Record 3 of Set 9 : tocopilla
# Processing Record 4 of Set 9 : srednekolymsk
# City not found. Looking for next value.
# Processing Record 5 of Set 9 : khuzdar
# Processing Record 6 of Set 9 : boguchany
# Processing Record 7 of Set 9 : palaia fokaia
# Processing Record 8 of Set 9 : arani
# City not found. Looking for next value.
# Processing Record 9 of Set 9 : bubaque
# City not found. Looking for next value.
# Processing Record 10 of Set 9 : linqiong
# Processing Record 11 of Set 9 : gizo
# Processing Record 12 of Set 9 : vilhena
# Processing Record 13 of Set 9 : shiyan
# Processing Record 14 of Set 9 : palmer
# Processing Record 15 of Set 9 : xuddur
# Processing Record 16 of Set 9 : vitorino freire
# City not found. Looking for next value.
# Processing Record 17 of Set 9 : lola
# Processing Record 18 of Set 9 : ust-kulom
# Processing Record 19 of Set 9 : khilok
# Processing Record 20 of Set 9 : morgan city
# Processing Record 21 of Set 9 : buala
# Processing Record 22 of Set 9 : marquette
# Processing Record 23 of Set 9 : kamphaeng phet
# Processing Record 24 of Set 9 : elwood
# Processing Record 25 of Set 9 : la grande
# Processing Record 26 of Set 9 : namatanai
# Processing Record 27 of Set 9 : ust-nera
# Processing Record 28 of Set 9 : konya
# City not found. Looking for next value.
# Processing Record 29 of Set 9 : kamaishi
# Processing Record 30 of Set 9 : beringovskiy
# Processing Record 31 of Set 9 : tual
# Processing Record 32 of Set 9 : francisco beltrao
# Processing Record 33 of Set 9 : viana
# Processing Record 34 of Set 9 : homer
# Processing Record 35 of Set 9 : port alfred
# Processing Record 36 of Set 9 : benalla
# Processing Record 37 of Set 9 : passo de camaragibe
# Processing Record 38 of Set 9 : athens
# City not found. Looking for next value.
# Processing Record 39 of Set 9 : quatre cocos
# Processing Record 40 of Set 9 : nauta
# Processing Record 41 of Set 9 : kenai
# Processing Record 42 of Set 9 : oak harbor
# Processing Record 43 of Set 9 : kiruna
# Processing Record 44 of Set 9 : sayyan
# Processing Record 45 of Set 9 : vallenar
# Processing Record 46 of Set 9 : tiquisate
# Processing Record 47 of Set 9 : gogrial
# Processing Record 48 of Set 9 : ukiah
# City not found. Looking for next value.
# Processing Record 49 of Set 9 : comodoro rivadavia
# City not found. Looking for next value.
# Processing Record 50 of Set 9 : grand-lahou
# Processing Record 0 of Set 10 : bakal
# Processing Record 1 of Set 10 : nishihara
# Processing Record 2 of Set 10 : gladstone
# Processing Record 3 of Set 10 : marsh harbour
# Processing Record 4 of Set 10 : fortuna
# Processing Record 5 of Set 10 : turgutlu
# City not found. Looking for next value.
# Processing Record 6 of Set 10 : belaya gora
# Processing Record 7 of Set 10 : tulare
# Processing Record 8 of Set 10 : kyshtovka
# City not found. Looking for next value.
# Processing Record 9 of Set 10 : kondagaon
# Processing Record 10 of Set 10 : pancol
# Processing Record 11 of Set 10 : flinders
# Processing Record 12 of Set 10 : port moresby
# Processing Record 13 of Set 10 : igarka
# Processing Record 14 of Set 10 : mancio lima
# Processing Record 15 of Set 10 : guanica
# Processing Record 16 of Set 10 : udomlya
# Processing Record 17 of Set 10 : volterra
# Processing Record 18 of Set 10 : nikolsk
# Processing Record 19 of Set 10 : kerrville
# Processing Record 20 of Set 10 : sala
# Processing Record 21 of Set 10 : vestmannaeyjar
# Processing Record 22 of Set 10 : micheweni
# Processing Record 23 of Set 10 : port macquarie
# Processing Record 24 of Set 10 : tecoanapa
# Processing Record 25 of Set 10 : kibre mengist
# Processing Record 26 of Set 10 : sobolevo
# City not found. Looking for next value.
# Processing Record 27 of Set 10 : puri
# Processing Record 28 of Set 10 : nador
# Processing Record 29 of Set 10 : touros
# Processing Record 30 of Set 10 : veraval
# Processing Record 31 of Set 10 : skibbereen
# Processing Record 32 of Set 10 : leshukonskoye
# Processing Record 33 of Set 10 : verkhnyaya toyma
# Processing Record 34 of Set 10 : paamiut
# Processing Record 35 of Set 10 : qorveh
# Processing Record 36 of Set 10 : orlik
# Processing Record 37 of Set 10 : kununurra
# Processing Record 38 of Set 10 : constantine
# Processing Record 39 of Set 10 : sao felix do xingu
# Processing Record 40 of Set 10 : manikpur
# Processing Record 41 of Set 10 : kamenka
# Processing Record 42 of Set 10 : olafsvik
# Processing Record 43 of Set 10 : karasburg
# Processing Record 44 of Set 10 : dawei
# Processing Record 45 of Set 10 : bardiyah
# Processing Record 46 of Set 10 : kropotkin
# City not found. Looking for next value.
# Processing Record 47 of Set 10 : yongan
# Processing Record 48 of Set 10 : merke
# Processing Record 49 of Set 10 : kloulklubed
# Processing Record 50 of Set 10 : baruun-urt
# Processing Record 0 of Set 11 : mezen
# Processing Record 1 of Set 11 : the valley
# Processing Record 2 of Set 11 : guozhen
# Processing Record 3 of Set 11 : orange
# Processing Record 4 of Set 11 : faya
# Processing Record 5 of Set 11 : korla
# Processing Record 6 of Set 11 : ixtapa
# Processing Record 7 of Set 11 : trinidad
# Processing Record 8 of Set 11 : henties bay
# Processing Record 9 of Set 11 : waipawa
# Processing Record 10 of Set 11 : poum
# Processing Record 11 of Set 11 : charlottesville
# Processing Record 12 of Set 11 : ingham
# Processing Record 13 of Set 11 : lodeynoye pole
# City not found. Looking for next value.
# Processing Record 14 of Set 11 : burnie
# Processing Record 15 of Set 11 : portland
# Processing Record 16 of Set 11 : basco
# Processing Record 17 of Set 11 : biltine
# Processing Record 18 of Set 11 : poli
# Processing Record 19 of Set 11 : san ramon
# Processing Record 20 of Set 11 : podor
# Processing Record 21 of Set 11 : puerto baquerizo moreno
# Processing Record 22 of Set 11 : balabac
# Processing Record 23 of Set 11 : madingou
# Processing Record 24 of Set 11 : tankhoy
# Processing Record 25 of Set 11 : takapau
# Processing Record 26 of Set 11 : toora-khem
# Processing Record 27 of Set 11 : karlstad
# City not found. Looking for next value.
# Processing Record 28 of Set 11 : gemena
# Processing Record 29 of Set 11 : bulungu
# Processing Record 30 of Set 11 : adrar
# Processing Record 31 of Set 11 : port lincoln
# Processing Record 32 of Set 11 : avera
# City not found. Looking for next value.
# Processing Record 33 of Set 11 : pimentel
# Processing Record 34 of Set 11 : jaciara
# Processing Record 35 of Set 11 : iznoski
# City not found. Looking for next value.
# Processing Record 36 of Set 11 : coquimbo
# Processing Record 37 of Set 11 : taksimo
# Processing Record 38 of Set 11 : durazno
# Processing Record 39 of Set 11 : port hawkesbury
# Processing Record 40 of Set 11 : choix
# Processing Record 41 of Set 11 : tilaran
# City not found. Looking for next value.
# Processing Record 42 of Set 11 : dudinka
# Processing Record 43 of Set 11 : chimore
# Processing Record 44 of Set 11 : verkhoyansk
# Processing Record 45 of Set 11 : kreminna
# Processing Record 46 of Set 11 : ouro branco
# Processing Record 47 of Set 11 : almeirim
# Processing Record 48 of Set 11 : mafinga
# Processing Record 49 of Set 11 : jalu
# Processing Record 50 of Set 11 : vavozh
# Processing Record 0 of Set 12 : gat
# Processing Record 1 of Set 12 : para de minas
# Processing Record 2 of Set 12 : eenhana
# Processing Record 3 of Set 12 : harnai
# Processing Record 4 of Set 12 : mildura
# Processing Record 5 of Set 12 : pontianak
# Processing Record 6 of Set 12 : roberval
# Processing Record 7 of Set 12 : viedma
# Processing Record 8 of Set 12 : bathsheba
# Processing Record 9 of Set 12 : naujamiestis
# Processing Record 10 of Set 12 : riyadh
# Processing Record 11 of Set 12 : chunskiy
# Processing Record 12 of Set 12 : suoyarvi
# Processing Record 13 of Set 12 : kananga
# Processing Record 14 of Set 12 : casalpusterlengo
# Processing Record 15 of Set 12 : san juan
# Processing Record 16 of Set 12 : luderitz
# Processing Record 17 of Set 12 : salinas
# City not found. Looking for next value.
# Processing Record 18 of Set 12 : mudgee
# Processing Record 19 of Set 12 : longyearbyen
# Processing Record 20 of Set 12 : egvekinot
# Processing Record 21 of Set 12 : raudeberg
# Processing Record 22 of Set 12 : isiro
# Processing Record 23 of Set 12 : bayir
# Processing Record 24 of Set 12 : port-cartier
# Processing Record 25 of Set 12 : grand gaube
# Processing Record 26 of Set 12 : shamkhal
# Processing Record 27 of Set 12 : shakawe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame using data from above code by creating a dict
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

#count data above
weather_dict.count()
# Out:
# City          588
# Cloudiness    588
# Country       588
# Date          588
# Humidity      588
# Lat           588
# Lng           588
# Max Temp      588
# Wind Speed    588
# dtype: int64

# %%
#view data frame
weather_dict
# Out:
#                      City  Cloudiness Country        Date  Humidity    Lat  \
# 0                  Berlin         100      DE  1603248869        93  52.52
# 1                Tasiilaq         100      GL  1603248869        97  65.61
# 2         Bambous Virieux          40      MU  1603248869        83 -20.34
# 3                   Yumen           0      CN  1603248869        27  40.28
# 4    Vila Franca do Campo          20      PT  1603248870        72  37.72
# ..                    ...         ...     ...         ...       ...    ...
# 583                 Bayir          75      TR  1603249073        82  37.27
# 584          Port-Cartier          20      CA  1603249025        84  50.03
# 585           Grand Gaube           1      MU  1603248844        68 -20.01
# 586              Shamkhal          40      RU  1603249074        87  43.06
# 587               Shakawe           0      BW  1603249074        23 -18.37
#
#        Lng  Max Temp  Wind Speed
# 0    13.41     52.00        6.93
# 1   -37.64     32.00       18.34
# 2    57.76     77.00       10.29
# 3    97.20     59.07       11.25
# 4   -25.43     59.00       12.75
# ..     ...       ...         ...
# 583  28.22     60.80        3.36
# 584 -66.87     37.99       10.29
# 585  57.66     77.00        8.99
# 586  47.34     55.40        6.71
# 587  21.85     68.27        6.51
#
# [588 rows x 9 columns]

# %%
#Create output file into a csv file
weather_dict.to_csv("../WeatherPy/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#There were no records with humidity > 100% - SKIPPING

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "red", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "yellow", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (10/19/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "orange", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (10/19/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "green", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (10/19/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# Create DataFrames for both north and south hemi
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
#Creating linear agression and scatter plot - use define function
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

#Define function for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call on linear_regression
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])
# Call on annotation
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.88

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.64

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.29

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.24

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.3

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.17

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.08

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.27
